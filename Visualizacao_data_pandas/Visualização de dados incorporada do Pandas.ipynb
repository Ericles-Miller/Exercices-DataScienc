# %% [markdown]
# # Visualização de dados incorporada do Pandas
#
# Nesta palestra, aprenderemos sobre capacidades integradas de pandas para visualização de dados. É construído em matplotlib, mas foi inserido no pandas para um uso mais fácil!
#
# Vamos dar uma olhada!

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
#import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Os dados
#
# Existem alguns arquivos csv de dados falsos que você pode ler como dados:

# %%
df1 = pd.read_csv('df1',index_col=0)
df2 = pd.read_csv('df2')

# %% [markdown]
# ## Folhas de estilo
#
# Matplotlib tem [folhas de estilo](http://matplotlib.org/gallery.html#style_sheets) que você pode usar para tornar seus plots mais agradáveis. Essas folhas de estilo incluem plot_bmh, plot_fivethirtyeight, plot_ggplot e muito mais. Eles basicamente criam um conjunto de regras de estilo que seus plots seguirão. Eu recomendo usá-los dado que eles farão seus plots terem uma aparência muito mais profissional. Você pode até mesmo criar o seu próprio caso você deseja que os gráficos de sua empresa tenham todos o mesmo aspecto (é um pouco tedioso para criar).
#
# Aqui é como usá-los.
#
# ** Antes de plt.style.use (), seus plots são assim: **

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Aplicando o estilo:

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
#existem varios tipos se temas para serem usados

# %% [markdown]
# Now your plots look like this:

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('bmh')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use('ggplot')

# %% [markdown]
# Vamos ficar com o estilo ggplot e, na verdade, mostramos como utilizar os recursos de traçabilidade embutidos no pandas!

# %% [markdown]
# # Tipos de plotagem
#
# Existem vários tipos de plots incorporados aos pandas, a maioria deles plots estatísticos por natureza:
#
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie
#
# Você também pode simplesmente chamar df.plot (kind = 'hist') ou substituir esse argumento por qualquer um dos termos-chave mostrados na lista acima (por exemplo, 'caixa', 'barh', etc.)
# ___

# %% [markdown]
# Vamos começar por eles!
#
# ## Área

# %%
df2.plot.area(alpha=0.4)
#alpha para transparencia
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Barplots

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)# stacked usa para juntar todas os valores em um 
#unica barra
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Histogramas

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Line Plots

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12,3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'df1.index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_24707/1407830292.py in <module>
# ----> 1 df1.plot.line(x='df1.index', y='B', figsize=(12,3))
#
# ~/.local/lib/python3.9/site-packages/pandas/plotting/_core.py in line(self, x, y, **kwargs)
#    1038         as coordinates.
#    1039         """
# -> 1040         return self(kind="line", x=x, y=y, **kwargs)
#    1041
#    1042     @Appender(
#
# ~/.local/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
#     939                 data = data.set_index(x)
#
# ~/.local/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'df1.index'

# %% [markdown]
# ## Scatter Plots

# %%
df1.plot.scatter(x='A',y='B', )

# %% [markdown]
# Você pode usar c para colorir com base em outro valor de coluna.
# Use o cmap para indicar o mapa de cores a ser usado.
# Para todos os colormaps, confira: http://matplotlib.org/users/colormaps.html

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
#cmap e o tema desejado
#c define a cor dos dados 
#s define a espessura dos pontos 
#figsize a dimensao da figura

# %% [markdown]
# Ou use s para indicar o tamanho com base em outra coluna. s parâmetro precisa ser uma matriz, não apenas o nome de uma coluna:

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*200)
#as vezes os pontos vem deo forma pequena por isso a mult por 200
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py:877: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# ## BoxPlots

# %%
df2.plot.box()

# %%
#Para plotar especificos box use a sintaxe
df2[['a','b']].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Hexagonal Bin Lote
#
# Útil para Dados Bivariados, alternativa ao Scatterplot:

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')
#grid size aumenta o tamanho dos pontos no graph

# %% [markdown]
# ____

# %% [markdown]
# ## Plot de Estimação de densidade de Kernel (Kernel Density Estimation - KDE)

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()
#

# %% [markdown]
# É isso aí! Espero que você possa ver por que esse método de traçado será muito mais fácil de usar do que full-on matplotlib, ele equilibra a facilidade de uso com controle sobre a figura. Muitas dos plots também aceitam argumentos adicionais de sua matriz matplotlib plt. ligar.
#
# Em seguida, vamos aprender sobre seaborn, que é uma biblioteca de visualização estatística projetada para trabalhar bem com os quadros de dados do pandas.
#
# Antes disso, porém, teremos um exercício rápido para você!
#
# # Bom trabalho!
